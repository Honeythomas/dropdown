# %%
import numpy as np
import pandas as pd

# %%
stemclass = pd.read_xlsx("teachassist.xlsx")
# Out:
# ------------------------------------------------------------------
# AttributeError                   Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 stemclass = pd.read_xlsx("teachassist.xlsx")
#
# AttributeError: module 'pandas' has no attribute 'read_xlsx'

# %%
pd_data_1 = pd.read_excel("teachassist.xlsx")
# Out:
# ------------------------------------------------------------------
# FileNotFoundError                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 pd_data_1 = pd.read_excel("teachassist.xlsx")
#
# File C:\Python311\Lib\site-packages\pandas\io\excel\_base.py:478, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     476 if not isinstance(io, ExcelFile):
#     477     should_close = True
# --> 478     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     479 elif engine and engine != io.engine:
#     480     raise ValueError(
#     481         "Engine should not be specified when passing "
#     482         "an ExcelFile - ExcelFile already has the engine set"
#     483     )
#
# ...

# %%
class = pd.read_csv("class.csv")
# Out:
#   Cell In[4], line 1
#     class = pd.read_csv("class.csv")
#           ^
# SyntaxError: invalid syntax

# %%
class = pd.read_csv('class.csv'
                   )
# Out:
#   Cell In[5], line 1
#     class = pd.read_csv('class.csv'
#           ^
# SyntaxError: invalid syntax

# %%
Class = pd.read_csv("Class.csv")
# Out:
# ------------------------------------------------------------------
# FileNotFoundError                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 Class = pd.read_csv("Class.csv")
#
# File C:\Python311\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
# ...

# %%
writer = pd.ExcelWriter("teachassist.xlsx")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 writer = pd.ExcelWriter("teachassist.xlsx")
#
# File C:\Python311\Lib\site-packages\pandas\io\excel\_openpyxl.py:56, in OpenpyxlWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#      43 def __init__(
#      44     self,
#      45     path: FilePath | WriteExcelBuffer | ExcelWriter,
#    (...)
#      54 ) -> None:
#      55     # Use the openpyxl module as the Excel writer.
# ---> 56     from openpyxl.workbook import Workbook
#      58     engine_kwargs = combine_kwargs(engine_kwargs, kwargs)
#      60     super().__init__(
#      61         path,
#      62         mode=mode,
#    (...)
#      65         engine_kwargs=engine_kwargs,
#      66     )
#
# ModuleNotFoundError: No module named 'openpyxl'

# %%
writer = pd.ExcelWriter("teachassist.xlsx")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 writer = pd.ExcelWriter("teachassist.xlsx")
#
# File C:\Python311\Lib\site-packages\pandas\io\excel\_openpyxl.py:56, in OpenpyxlWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#      43 def __init__(
#      44     self,
#      45     path: FilePath | WriteExcelBuffer | ExcelWriter,
#    (...)
#      54 ) -> None:
#      55     # Use the openpyxl module as the Excel writer.
# ---> 56     from openpyxl.workbook import Workbook
#      58     engine_kwargs = combine_kwargs(engine_kwargs, kwargs)
#      60     super().__init__(
#      61         path,
#      62         mode=mode,
#    (...)
#      65         engine_kwargs=engine_kwargs,
#      66     )
#
# ModuleNotFoundError: No module named 'openpyxl'

# %%
df = pd.ExcelWriter("teachassist.xlsx")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df = pd.ExcelWriter("teachassist.xlsx")
#
# File C:\Python311\Lib\site-packages\pandas\io\excel\_openpyxl.py:56, in OpenpyxlWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#      43 def __init__(
#      44     self,
#      45     path: FilePath | WriteExcelBuffer | ExcelWriter,
#    (...)
#      54 ) -> None:
#      55     # Use the openpyxl module as the Excel writer.
# ---> 56     from openpyxl.workbook import Workbook
#      58     engine_kwargs = combine_kwargs(engine_kwargs, kwargs)
#      60     super().__init__(
#      61         path,
#      62         mode=mode,
#    (...)
#      65         engine_kwargs=engine_kwargs,
#      66     )
#
# ModuleNotFoundError: No module named 'openpyxl'

# %%
pd.__version__
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 pd.__version__
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.0.1'

# %%
pd.read_excel('Class 7.xlsx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 pd.read_excel('Class 7.xlsx')
#
# File C:\Python311\Lib\site-packages\pandas\io\excel\_base.py:478, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     476 if not isinstance(io, ExcelFile):
#     477     should_close = True
# --> 478     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     479 elif engine and engine != io.engine:
#     480     raise ValueError(
#     481         "Engine should not be specified when passing "
#     482         "an ExcelFile - ExcelFile already has the engine set"
#     483     )
#
# ...

# %%
pd.read_excel('Class_7.xlsx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 pd.read_excel('Class_7.xlsx')
#
# File C:\Python311\Lib\site-packages\pandas\io\excel\_base.py:478, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     476 if not isinstance(io, ExcelFile):
#     477     should_close = True
# --> 478     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     479 elif engine and engine != io.engine:
#     480     raise ValueError(
#     481         "Engine should not be specified when passing "
#     482         "an ExcelFile - ExcelFile already has the engine set"
#     483     )
#
# ...

# %%
pd.read_excel('Class7.xlsx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 pd.read_excel('Class7.xlsx')
#
# File C:\Python311\Lib\site-packages\pandas\io\excel\_base.py:478, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     476 if not isinstance(io, ExcelFile):
#     477     should_close = True
# --> 478     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     479 elif engine and engine != io.engine:
#     480     raise ValueError(
#     481         "Engine should not be specified when passing "
#     482         "an ExcelFile - ExcelFile already has the engine set"
#     483     )
#
# ...

# %%
pd.read_excel('assist.xlsx')
# Out:
#     TEACH ASSIST  Unnamed: 1 Unnamed: 2             Unnamed: 3 Unnamed: 4
# 0             NaN        NaN        NaN                    NaN        NaN  \
# 1             NaN        NaN        NaN                    NaN        NaN
# 2             NaN        NaN        NaN                    NaN        NaN
# 3             NaN        NaN        NaN                    NaN        NaN
# 4           Class   Teacher     Subject              Text Book     Strand
# ..            ...        ...        ...                    ...        ...
# 185             6        NaN    English  The Pact with the Sun    Reading
# 186             6        NaN    English  The Pact with the Sun    Reading
# 187             6        NaN    English  The Pact with the Sun    Reading
# 188             6        NaN    English  The Pact with the Sun    Reading
# 189             6        NaN    English  The Pact with the Sun    Reading
#
#     Unnamed: 5 Unnamed: 6 Unnamed: 7
# 0          NaN        NaN        NaN  \
# ...

# %%
pd.read_excel('assist.xlsx', index_col=0)
# Out:
#               Unnamed: 1 Unnamed: 2             Unnamed: 3 Unnamed: 4
# TEACH ASSIST
# NaN                  NaN        NaN                    NaN        NaN  \
# NaN                  NaN        NaN                    NaN        NaN
# NaN                  NaN        NaN                    NaN        NaN
# NaN                  NaN        NaN                    NaN        NaN
# Class           Teacher     Subject              Text Book     Strand
# ...                  ...        ...                    ...        ...
# 6                    NaN    English  The Pact with the Sun    Reading
# 6                    NaN    English  The Pact with the Sun    Reading
# 6                    NaN    English  The Pact with the Sun    Reading
# 6                    NaN    English  The Pact with the Sun    Reading
# 6                    NaN    English  The Pact with the Sun    Reading
#
#               Unnamed: 5 Unnamed: 6 Unnamed: 7
# TEACH ASSIST
# NaN                  NaN        NaN        NaN  \
# ...

# %%
pd.read_excel('assist.xlsx', index_col=0, index_row=5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 pd.read_excel('assist.xlsx', index_col=0, index_row=5)
#
# TypeError: read_excel() got an unexpected keyword argument 'index_row'

# %%
pd.read_excel('assist1.xlsx', index_col=0)
# Out:
#            Teacher   Subject              Text Book    Strand Lesson #
# Curriculum
# CBSE            NaN  English            Honeysuckle  Reading        1A  \
# CBSE            NaN  English            Honeysuckle  Reading       NaN
# CBSE            NaN  English            Honeysuckle  Reading       NaN
# CBSE            NaN  English            Honeysuckle  Reading       NaN
# CBSE            NaN  English            Honeysuckle  Reading       NaN
# ...             ...      ...                    ...       ...      ...
# NaN             NaN  English  The Pact with the Sun   Reading      NaN
# NaN             NaN  English  The Pact with the Sun   Reading      NaN
# NaN             NaN  English  The Pact with the Sun   Reading      NaN
# NaN             NaN  English  The Pact with the Sun   Reading      NaN
# NaN             NaN  English  The Pact with the Sun   Reading      NaN
#
#                                  Lesson Topic #
# Curriculum
# ...

# %%
pd.read_excel('assist.xlsx', index_col=0)
# Out:
#            Teacher   Subject              Text Book    Strand Lesson #
# Curriculum
# CBSE            NaN  English            Honeysuckle  Reading        1A  \
# CBSE            NaN  English            Honeysuckle  Reading       NaN
# CBSE            NaN  English            Honeysuckle  Reading       NaN
# CBSE            NaN  English            Honeysuckle  Reading       NaN
# CBSE            NaN  English            Honeysuckle  Reading       NaN
# ...             ...      ...                    ...       ...      ...
# CBSE            NaN  English  The Pact with the Sun   Reading      NaN
# CBSE            NaN  English  The Pact with the Sun   Reading      NaN
# CBSE            NaN  English  The Pact with the Sun   Reading      NaN
# CBSE            NaN  English  The Pact with the Sun   Reading      NaN
# CBSE            NaN  English  The Pact with the Sun   Reading      NaN
#
#                                  Lesson Topic #
# Curriculum
# ...

# %%
pd.read_excel('assist.xlsx', index_col=0, usecols="A,C:E")
# Out:
#             Subject              Text Book    Strand
# Curriculum
# CBSE        English            Honeysuckle  Reading
# CBSE        English            Honeysuckle  Reading
# CBSE        English            Honeysuckle  Reading
# CBSE        English            Honeysuckle  Reading
# CBSE        English            Honeysuckle  Reading
# ...             ...                    ...       ...
# CBSE        English  The Pact with the Sun   Reading
# CBSE        English  The Pact with the Sun   Reading
# CBSE        English  The Pact with the Sun   Reading
# CBSE        English  The Pact with the Sun   Reading
# CBSE        English  The Pact with the Sun   Reading
#
# [185 rows x 3 columns]

# %%
pd.read_excel('assist.xlsx', index_col=0, sheet_name=1)
# Out:
#            Class Teacher   Subject      Text Book   Strand Lesson #
# Curriculum
# CBSE           7      NaN  English  AN ALIEN HAND  Reading        1  \
# CBSE           7      NaN  English  AN ALIEN HAND  Reading      NaN
# CBSE           7      NaN  English  AN ALIEN HAND  Reading      NaN
# CBSE           7      NaN  English  AN ALIEN HAND  Reading      NaN
# CBSE           7      NaN  English  AN ALIEN HAND  Reading      NaN
# ...          ...      ...      ...            ...      ...      ...
# CBSE           7      NaN  ENGLISH     HONEY COMB  Reading      10A
# CBSE           7      NaN  ENGLISH     HONEY COMB  Reading      NaN
# CBSE           7      NaN  ENGLISH     HONEY COMB  Reading      NaN
# CBSE           7      NaN  ENGLISH     HONEY COMB  Reading      NaN
# CBSE           7      NaN  ENGLISH     HONEY COMB  Reading      NaN
#
#                            Lesson Topic #
# Curriculum
# CBSE             The Tiny Teacher     1.1  \
# ...

# %%
pd.read_excel('assist.xlsx', index_col=0,usecols="A,C:E", sheet_name=1)
# Out:
#            Teacher   Subject      Text Book
# Curriculum
# CBSE            NaN  English  AN ALIEN HAND
# CBSE            NaN  English  AN ALIEN HAND
# CBSE            NaN  English  AN ALIEN HAND
# CBSE            NaN  English  AN ALIEN HAND
# CBSE            NaN  English  AN ALIEN HAND
# ...             ...      ...            ...
# CBSE            NaN  ENGLISH     HONEY COMB
# CBSE            NaN  ENGLISH     HONEY COMB
# CBSE            NaN  ENGLISH     HONEY COMB
# CBSE            NaN  ENGLISH     HONEY COMB
# CBSE            NaN  ENGLISH     HONEY COMB
#
# [152 rows x 3 columns]

# %%
pd.read_excel('assist.xlsx', index_col=0,usecols="A:B,D:F", sheet_name=1)
# Out:
#            Class  Subject      Text Book   Strand
# Curriculum
# CBSE           7  English  AN ALIEN HAND  Reading
# CBSE           7  English  AN ALIEN HAND  Reading
# CBSE           7  English  AN ALIEN HAND  Reading
# CBSE           7  English  AN ALIEN HAND  Reading
# CBSE           7  English  AN ALIEN HAND  Reading
# ...          ...      ...            ...      ...
# CBSE           7  ENGLISH     HONEY COMB  Reading
# CBSE           7  ENGLISH     HONEY COMB  Reading
# CBSE           7  ENGLISH     HONEY COMB  Reading
# CBSE           7  ENGLISH     HONEY COMB  Reading
# CBSE           7  ENGLISH     HONEY COMB  Reading
#
# [152 rows x 4 columns]

# %%
pd.read_excel('assist.xlsx', index_col=0,usecols="A:B,D:F", sheet_name=1, skiprows[52:54])
# Out:
#   Cell In[16], line 1
#     pd.read_excel('assist.xlsx', index_col=0,usecols="A:B,D:F", sheet_name=1, skiprows[52:54])
#                                                                                              ^
# SyntaxError: positional argument follows keyword argument

# %%
pd.read_excel('assist.xlsx', index_col=0,usecols="A:B,D:F", sheet_name=1)
# Out:
#            Class  Subject      Text Book   Strand
# Curriculum
# CBSE           7  English  AN ALIEN HAND  Reading
# CBSE           7  English  AN ALIEN HAND  Reading
# CBSE           7  English  AN ALIEN HAND  Reading
# CBSE           7  English  AN ALIEN HAND  Reading
# CBSE           7  English  AN ALIEN HAND  Reading
# ...          ...      ...            ...      ...
# CBSE           7  ENGLISH     HONEY COMB  Reading
# CBSE           7  ENGLISH     HONEY COMB  Reading
# CBSE           7  ENGLISH     HONEY COMB  Reading
# CBSE           7  ENGLISH     HONEY COMB  Reading
# CBSE           7  ENGLISH     HONEY COMB  Reading
#
# [152 rows x 4 columns]
